# %%
import requests
import json
import pandas as pd

# %%
for i in range(1, 10):
    url = f'https://api.themoviedb.org/3/discover/movie?page={i}&api_key=26321807a85638c70b1948a5b58528f4'
    r = requests.get(url)
    yay = pd.DataFrame(r.json()['results'])
yay
# Out:
#     popularity  vote_count  video                       poster_path      id  \
# 0       30.694        7627  False  /2y4dmgWYRMYXdD1UyJVcn2HSd1D.jpg     280
# 1       32.288        4380  False  /xnopI5Xtky18MPhK40cZAGAOVeV.jpg  287947
# 2       29.625        1956  False  /m5LqnnkN09124CSE8yGskeCv3kb.jpg  543540
# 3       37.890       10486  False  /to0spRl1CMDvyUbOnbb4fTk3VAd.jpg  383498
# 4       27.577        1880  False  /gRdfLVVf6FheOw6mw6wOsKhZG1l.jpg     646
# 5       30.069        7738  False  /2mkFzf168xJrV6Leqq0bjqOlJCK.jpg    2048
# 6       25.142        5638  False  /qey0tdcOp9kCDdEZuJ87yE3crSe.jpg  254128
# 7       28.815       10257  False  /rdPGUJhadPg7FGFNzavib0iwTor.jpg  419430
# 8       30.807       11514  False  /noUp0XOqIcmgefRnRZa1nhtRvWO.jpg  205596
# 9       28.130       12947  False  /fTplI1NCSuEDP4ITLcTps739fcC.jpg   12445
# 10      26.005       12035  False  /93Y9BGx8blzmZOPSoivkFfaifqU.jpg     585
# ...

# %%
yay.shape
# Out:
# (20, 14)
